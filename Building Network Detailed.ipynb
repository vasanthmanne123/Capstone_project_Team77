# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import networkx as nx

# %%
#Loading cleaned data 
df=pd.read_csv('data/globalterrorism_cleaned.csv',encoding='ISO-8859-1', low_memory=False)
print("Data imported successfully")
# Out:
# Data imported successfully

# %%
df
# Out:
#         year  extended             country                       region  \
# 0       1970         0  Dominican Republic  Central America & Caribbean
# 1       1970         0              Mexico                North America
# 2       1970         0         Philippines               Southeast Asia
# 3       1970         0              Greece               Western Europe
# 4       1970         0               Japan                    East Asia
# 5       1970         0       United States                North America
# 6       1970         0             Uruguay                South America
# 7       1970         0       United States                North America
# 8       1970         0       United States                North America
# 9       1970         0       United States                North America
# 10      1970         0       United States                North America
# 11      1970         0       United States                North America
# ...

# %%
plt.figure(figsize=(20,20))
G=nx.from_pandas_edgelist(df[0:5], 'attacktype', 'country')
nx.draw_networkx(G)
plt.show()
# Out:
# C:\Users\purushotham\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
plt.figure(figsize=(20,20))
G=nx.from_pandas_edgelist(df[0:15], 'attacktype', 'country')
nx.draw_networkx(G)
plt.show()

# %%
plt.figure(figsize=(20,20))
G=nx.from_pandas_edgelist(df[0:25], 'attacktype', 'country')
nx.draw_networkx(G)
plt.show()

# %%
plt.figure(figsize=(20,20))
G=nx.from_pandas_edgelist(df[0:40], 'attacktype', 'country')
nx.draw_networkx(G)
plt.show()

# %%
plt.figure(figsize=(20,20))
G=nx.from_pandas_edgelist(df[0:75], 'attacktype', 'country')
nx.draw_networkx(G)
plt.show()

# %%
plt.figure(figsize=(20,20))
G=nx.from_pandas_edgelist(df, 'attacktype', 'country')
nx.draw_networkx(G)
plt.show()
